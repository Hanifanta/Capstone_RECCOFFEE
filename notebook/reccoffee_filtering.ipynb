# %% [markdown]
# ##**Import Library**

# %%
# Data loading and data analysis
import pandas as pd

# Data preprocessing
from sklearn.preprocessing import LabelEncoder

# Modelling
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ##**Data Preprocession**

# %%
coffee = pd.read_csv('/content/coffee_clean.csv')
coffee.head(5)
# Out:
#    Unnamed: 0                        name  \
# 0           0     “Sweety” Espresso Blend
# 1           1        Flora Blend Espresso
# 2           2    Ethiopia Shakiso Mormora
# 3           3          Ethiopia Suke Quto
# 4           4  Ethiopia Gedeb Halo Beriti
#
#                                              origin  rating  \
# 0                                  Panama; Ethiopia      95
# 1                              Africa; Asia Pacific      94
# 2                      Guji Zone, southern Ethiopia      92
# 3  Guji Zone, Oromia Region, south-central Ethiopia      92
# 4     Gedeb District, Gedeo Zone, southern Ethiopia      94
#
#                      roaster  aroma  acid  body  flavor  aftertaste  \
# 0                     A.R.C.    9.0   0.0   9.0     9.0         9.0
# 1                     A.R.C.    9.0   0.0   9.0     9.0         8.0
# 2               Revel Coffee    9.0   8.0   8.0     9.0         8.0
# 3                Roast House    8.0   8.0   9.0     9.0         8.0
# 4  Big Creek Coffee Roasters    9.0   9.0   9.0     9.0         8.0
#
#                                               desc_1  \
# 0  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  Evaluated as espresso. Sweetly tart, floral-to...
# 2  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                               desc_2  \
# 0  An espresso blend comprised of coffees from Pa...
# 1  An espresso blend comprised of coffees from Af...
# 2  This coffee tied for the third-highest rating ...
# 3  This coffee tied for the third-highest rating ...
# 4  Southern Ethiopia coffees like this one are pr...
#
#                                               desc_3
# 0  A radiant espresso blend that shines equally i...
# 1  A floral-driven straight shot, amplified with ...
# 2  A gently spice-toned, floral- driven wet-proce...
# 3  Lavender-like flowers and hints of zesty pink ...
# 4  A deeply and generously lush cup saved from se...

# %%
# Drop unused column
coffee.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
data = coffee.filter(['aroma', 'acid', 'body', 'flavor', 'aftertaste', 'name'])
data.head(5)
# Out:
#    aroma  acid  body  flavor  aftertaste                        name
# 0    9.0   0.0   9.0     9.0         9.0     “Sweety” Espresso Blend
# 1    9.0   0.0   9.0     9.0         8.0        Flora Blend Espresso
# 2    9.0   8.0   8.0     9.0         8.0    Ethiopia Shakiso Mormora
# 3    8.0   8.0   9.0     9.0         8.0          Ethiopia Suke Quto
# 4    9.0   9.0   9.0     9.0         8.0  Ethiopia Gedeb Halo Beriti

# %%
data.rename(columns=({'name':'label'}), inplace=True)
data.head(5)
# Out:
#    aroma  acid  body  flavor  aftertaste                       label
# 0    9.0   0.0   9.0     9.0         9.0     “Sweety” Espresso Blend
# 1    9.0   0.0   9.0     9.0         8.0        Flora Blend Espresso
# 2    9.0   8.0   8.0     9.0         8.0    Ethiopia Shakiso Mormora
# 3    8.0   8.0   9.0     9.0         8.0          Ethiopia Suke Quto
# 4    9.0   9.0   9.0     9.0         8.0  Ethiopia Gedeb Halo Beriti

# %% [markdown]
# ##**Modelling**

# %%
X = data.iloc[:, 0:-1]
y = data.iloc[:, -1]

# %%
model = svm.SVC()
model_2 = KNeighborsClassifier()
model_3 = RandomForestClassifier(n_estimators=100)

# %% [markdown]
# **SVM**

# %%
model.fit(X.values, y)
# Out:
# SVC()

# %%
svm_pred = model.predict([[9.0, 0.0, 9.0, 9.0, 8.0]])
print(svm_pred)
# Out:
# ['Espresso Blend']

# %%
coffee[coffee['name'] == 'Espresso Blend']
# Out:
#                 name                                        origin  rating  \
# 170   Espresso Blend                                 Not disclosed      90
# 231   Espresso Blend                         Brazil; Peru; Ecuador      92
# 498   Espresso Blend                                      Ethiopia      91
# 1184  Espresso Blend                            Brazil; East Timor      93
# 1549  Espresso Blend                                 Not disclosed      94
# 1569  Espresso Blend             Ethiopia; El Salvador; Costa Rica      92
# 1771  Espresso Blend                                 Not disclosed      92
# 1792  Espresso Blend                           Guatemala; Ethiopia      92
# 1906  Espresso Blend  India, Brazil, Ethiopia, Indonesia, Colombia      92
# 2159  Espresso Blend         Ethiopia; Guatemala; Colombia; Brazil      92
#
#                roaster  aroma  acid  body  flavor  aftertaste  \
# 170               Amor    9.0   0.0   8.0     8.0         7.0
# 231   Pop Coffee Works    9.0   0.0   8.0     8.0         8.0
# 498    Mellower Coffee    8.0   0.0   8.0     8.0         8.0
# 1184   Souvenir Coffee    9.0   0.0   8.0     9.0         8.0
# 1549      Queen Coffee    9.0   0.0   9.0     9.0         8.0
# 1569     Warm Air Kafe    8.0   0.0   8.0     9.0         8.0
# 1771         Luv Moshi    9.0   0.0   8.0     9.0         7.0
# 1792       LECO Coffee    9.0   0.0   8.0     8.0         8.0
# 1906    Ba Yang Coffee    8.0   0.0   9.0     9.0         7.0
# 2159       Muka Coffee    8.0   0.0   9.0     8.0         8.0
#
#                                                  desc_1  \
# 170   Evaluated as espresso. Simple but round, reson...
# 231   Evaluated as espresso. Crisply sweet, lively, ...
# 498   Evaluated as espresso. Chocolaty, richly sweet...
# 1184  Evaluated as espresso. Crisply sweet, chocolat...
# 1549  Evaluated as espresso. Crisply sweet, cocoa-dr...
# 1569  Evaluated as espresso. Crisply sweet-tart, fru...
# 1771  Evaluated as espresso. Chocolaty, deep-toned. ...
# 1792  Evaluated as espresso. Delicately bright, subt...
# 1906  Evaluated as espresso. Chocolaty and nut-toned...
# 2159  Evaluated as espresso. Crisply sweet, fruit-to...
#
#                                                  desc_2  \
# 170   Amor is a food and beverage company based in B...
# 231   A blend of natural-processed Brazil and washed...
# 498   A blend of washed- and natural-process coffees...
# 1184  A blend of 75% Brazil and 25% East Timor coffe...
# 1549  Queen Coffee (EMPRESS COFFEE 女皇咖啡 ) is a speci...
# 1569  A blend of two Ethiopia, one El Salvador, and ...
# 1771  Luv Moshi is a Taiwan-based specialty coffee r...
# 1792  An espresso blend comprised of a wet-processed...
# 1906  A blend of coffees from India, Brazil, Ethiopi...
# 2159  A blend of four coffees: washed Ethiopia, Guat...
#
#                                                  desc_3
# 170   A darker-roasted espresso in the robust tradit...
# 231   A chocolaty espresso blend with bright notes o...
# 498   A bold, deeply chocolate-toned espresso blend ...
# 1184  A friendly espresso blend, chocolaty and nutty...
# 1549  A deftly roasted, cocoa-driven espresso blend ...
# 1569  A berry-toned, crisply chocolaty espresso blen...
# 1771  An espresso blend with leading notes of dark c...
# 1792  A delicately fruit-centered espresso blend wit...
# 1906  A friendly, accessible, richly chocolate-drive...
# 2159  A deep-toned, deftly medium-roasted espresso b...

# %%
coffee[(coffee['name'] == 'Espresso Blend') & (coffee['aroma'] == 9.0) & (coffee['acid'] == 0.0) & (coffee['body'] == 9.0) & (coffee['flavor'] == 9.0) & (coffee['aftertaste'] == 8.0)]
# Out:
#                 name         origin  rating       roaster  aroma  acid  body  \
# 1549  Espresso Blend  Not disclosed      94  Queen Coffee    9.0   0.0   9.0
#
#       flavor  aftertaste                                             desc_1  \
# 1549     9.0         8.0  Evaluated as espresso. Crisply sweet, cocoa-dr...
#
#                                                  desc_2  \
# 1549  Queen Coffee (EMPRESS COFFEE 女皇咖啡 ) is a speci...
#
#                                                  desc_3
# 1549  A deftly roasted, cocoa-driven espresso blend ...

# %% [markdown]
# **KN Classifier**

# %%
model_2.fit(X.values, y)
# Out:
# KNeighborsClassifier()

# %%
kn_pred = model_2.predict([[9.0, 0.0, 9.0, 9.0, 8.0]])
print(kn_pred)
# Out:
# ['Ace Espresso']

# %%
coffee[coffee['name'] == 'Ace Espresso']
# Out:
#              name             origin  rating           roaster  aroma  acid  \
# 30   Ace Espresso   Mexico; Ethiopia      94  Propeller Coffee    9.0   0.0
# 544  Ace Espresso  Burundi; Colombia      93  Propeller Coffee    9.0   0.0
#
#      body  flavor  aftertaste  \
# 30    9.0     9.0         8.0
# 544   8.0     9.0         8.0
#
#                                                 desc_1  \
# 30   Evaluated as espresso. Floral-toned, lively. B...
# 544  Evaluated as espresso. Deeply cocoa- and nut-t...
#
#                                                 desc_2  \
# 30   A blend of coffees from Mexico and Ethiopia. P...
# 544  This coffee tied for the second-highest rating...
#
#                                                 desc_3
# 30   A floral-toned, richly sweet espresso blend: b...
# 544  Propeller’s Ace Espresso Blend comprises an ev...

# %%
coffee[(coffee['name'] == 'Ace Espresso') & (coffee['aroma'] == 9.0) & (coffee['acid'] == 0.0) & (coffee['body'] == 9.0) & (coffee['flavor'] == 9.0) & (coffee['aftertaste'] == 8.0)]
# Out:
#             name            origin  rating           roaster  aroma  acid  \
# 30  Ace Espresso  Mexico; Ethiopia      94  Propeller Coffee    9.0   0.0
#
#     body  flavor  aftertaste  \
# 30   9.0     9.0         8.0
#
#                                                desc_1  \
# 30  Evaluated as espresso. Floral-toned, lively. B...
#
#                                                desc_2  \
# 30  A blend of coffees from Mexico and Ethiopia. P...
#
#                                                desc_3
# 30  A floral-toned, richly sweet espresso blend: b...

# %% [markdown]
# **Random Forest**

# %%
model_3.fit(X.values, y)
# Out:
# RandomForestClassifier()

# %%
rf_pred = model_2.predict([[9.0, 0.0, 9.0, 9.0, 8.0]])
print(rf_pred)
# Out:
# ['Ace Espresso']

# %%
coffee[coffee['name'] == 'Ace Espresso']
# Out:
#              name             origin  rating           roaster  aroma  acid  \
# 30   Ace Espresso   Mexico; Ethiopia      94  Propeller Coffee    9.0   0.0
# 544  Ace Espresso  Burundi; Colombia      93  Propeller Coffee    9.0   0.0
#
#      body  flavor  aftertaste  \
# 30    9.0     9.0         8.0
# 544   8.0     9.0         8.0
#
#                                                 desc_1  \
# 30   Evaluated as espresso. Floral-toned, lively. B...
# 544  Evaluated as espresso. Deeply cocoa- and nut-t...
#
#                                                 desc_2  \
# 30   A blend of coffees from Mexico and Ethiopia. P...
# 544  This coffee tied for the second-highest rating...
#
#                                                 desc_3
# 30   A floral-toned, richly sweet espresso blend: b...
# 544  Propeller’s Ace Espresso Blend comprises an ev...

# %%
coffee[(coffee['name'] == 'Ace Espresso') & (coffee['aroma'] == 9.0) & (coffee['acid'] == 0.0) & (coffee['body'] == 9.0) & (coffee['flavor'] == 9.0) & (coffee['aftertaste'] == 8.0)]
# Out:
#             name            origin  rating           roaster  aroma  acid  \
# 30  Ace Espresso  Mexico; Ethiopia      94  Propeller Coffee    9.0   0.0
#
#     body  flavor  aftertaste  \
# 30   9.0     9.0         8.0
#
#                                                desc_1  \
# 30  Evaluated as espresso. Floral-toned, lively. B...
#
#                                                desc_2  \
# 30  A blend of coffees from Mexico and Ethiopia. P...
#
#                                                desc_3
# 30  A floral-toned, richly sweet espresso blend: b...
